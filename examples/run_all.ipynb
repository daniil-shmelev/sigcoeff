# %%
#!pip install git+https://github.com/daniil-shmelev/sigcoeff.git

# %% [markdown]
# # Dependence of Error on Coefficient Depth

# %% [markdown]
# Average errors when computing $S(x)^{(1,...,n)}$ over random paths constrained to $[0, 1]^d$, with
# path length $L = 150$ and scaling depth $M = 3$.

# %%
# %run depth_error
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.85it/s]

# %% [markdown]
# # Dependence of Time Complexity on Coefficient Depth

# %% [markdown]
# Dependence of runtime on coefficient depth, averaged over random paths constrained to $[0, 1]^d$, with path length
# $L = 10,000$, scaling depth $M = 1$ and PDE dyadic order set to $1$. For comparability, all computations
# are performed using CUDA.

# %%
# %run depth_complexity

# %%
# %run depth_complexity_chen

# %% [markdown]
# # Dependence of Error on Scaling Depth (M)

# %% [markdown]
# Average errors when computing $S(x)^{(1,2,...,n)}$ for random paths in $[0, 1]^d$, with path lengths $L = 100$ (top),
# $L = 500$ (middle) and $L = 1000$ (bottom). Dyadic order of the PDE solver is set to $3$.

# %%
# %run M_error
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:56<00:00,  4.16s/it]
